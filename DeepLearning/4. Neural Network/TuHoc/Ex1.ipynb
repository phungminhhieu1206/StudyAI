# %% [markdown]
# ## Bài 1:
# * Xem lại công thức tính node trong hidden layer,
# * biểu diễn bài toán dưới dạng ma trận.
# * Hiểu hết và chạy lại code (softmax, cross_entropy, batch update).

# %% [markdown]
# ### 1.1. Công thức tính node
# * Giá trị node sau khi tính tổng linear
# * Giá trị node sau khi tính activation function

# %%
from IPython.display import Image
Image("ex1_1.jpg")

# %% [markdown]
# ### 1.2. Biểu diễn bài toán dưới dạng ma trận

# %%
from IPython.display import Image
Image("ex1_2.jpg")

# %% [markdown]
# ### 1.3. Chạy lại code trong file MNIST.ipynb (OK)
