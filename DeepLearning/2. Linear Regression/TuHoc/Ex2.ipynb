# %% [markdown]
# ## Bài 2:
# * Tự biểu diễn lại bài toán, bắt đầu từ 1 điểm dữ liệu (xi, yi)
# * -> model, loss function, đạo hàm với từng biến.
# * Xong biểu diễn dưới dạng vector.
# * Tính đạo hàm của cả ma trận W với loss function thay vì từng thành phần w0, w1.
# * Chứng minh lại: dJ/dW = X.T * (Y^-Y)

# %%
from IPython.display import Image
Image("ex2.jpg")
